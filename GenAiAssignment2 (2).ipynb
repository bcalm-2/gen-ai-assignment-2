# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (5.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.25.2)
# Requirement already satisfied: huggingface-hub<2.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (1.7.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from transformers) (0.24.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (1.4.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (0.28.1)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (0.24.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (4.15.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (4.12.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (0.16.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers) (0.1.2)

# %%
from transformers import GPT2LMHeadModel, GPT2Tokenizer

tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
model = GPT2LMHeadModel.from_pretrained("gpt2")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
# Array of prompts
prompts = [
    "The future of education is",
    "Artificial Intelligence will",
    "India in 2050 will be"
]

def generate_text(prompt, top_k, temperature):
    inputs = tokenizer.encode(prompt, return_tensors="pt")

    output = model.generate(
        inputs,
        max_new_tokens=50,
        do_sample=True,
        top_k=top_k,
        temperature=temperature
    )

    return tokenizer.decode(output[0], skip_special_tokens=True)

# Run for all prompts
for prompt in prompts:
    print("\nPrompt:", prompt)
    result = generate_text(prompt, top_k=40, temperature=0.7)
    print("Output:", result)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Prompt: The future of education is
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Output: The future of education is uncertain. While progress has been made, it will take a while before students get the confidence to move forward.
#
# "I am very happy that we have the support of the Government and are taking steps to improve the quality of life.
#
#
#
# Prompt: Artificial Intelligence will
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Output: Artificial Intelligence will be able to understand everything from human movements to the world around us in the coming decades.
#
# The new technology will enable us to know about events and events in order to make better predictions and decisions.
#
# The new technology will enable us to
#
# Prompt: India in 2050 will be
# Output: India in 2050 will be a 'tough and tough and really good thing,' said Mr Bhattacharya.
#
# "It's about keeping pace with the pace of the next century and the challenge of having the most advanced country in the world," he added.

# %%
# Different values to test
temperatures = [0.7, 1.0, 1.3]
top_k_values = [20, 40, 80]

# Store results
results = []

for prompt in prompts:
    for temp in temperatures:
        for k in top_k_values:

            output = generate_text(prompt, top_k=k, temperature=temp)

            results.append({
                "prompt": prompt,
                "temperature": temp,
                "top_k": k,
                "output": output
            })

# Print results clearly
for r in results:
    print("\n----------------------------------")
    print("Prompt:", r["prompt"])
    print("Temperature:", r["temperature"])
    print("Top_k:", r["top_k"])
    print("Output:", r["output"])
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ----------------------------------
# Prompt: The future of education is
# Temperature: 0.7
# Top_k: 20
# Output: The future of education is now in doubt.
#
# A new report from the Institute for Education Research has revealed that the cost of teaching English has increased by just 5% over the past decade.
#
# The report said: "The biggest increase in the number of students at
#
# ----------------------------------
# Prompt: The future of education is
# Temperature: 0.7
# Top_k: 40
# Output: The future of education is uncertain, and many parents are trying to make their children feel empowered to work. And the fact that our country is still in the midst of a recession — which is a huge problem for young people — is a big reason why we're seeing an increase
#
# ----------------------------------
# Prompt: The future of education is
# Temperature: 0.7
# Top_k: 80
# Output: The future of education is going to be determined by many factors, including the pace at which it has been built. It is not necessarily a matter of the quality of education, but the quality of education that is available to students, particularly those studying in high-quality academic environments
#
# ----------------------------------
# Prompt: The future of education is
# Temperature: 1.0
# Top_k: 20
# Output: The future of education is very uncertain," he concluded. "The next generation needs to do something to prepare them for this new reality."
#
# ----------------------------------
# Prompt: The future of education is
# Temperature: 1.0
# Top_k: 40
# Output: The future of education is about developing ideas that challenge the status quo at the world's elite-driven institutions," he told BuzzFeed News.
#
# And while "globalism does not yet exist within the academic establishment", he said, "it will soon. In fact, some
#
# ----------------------------------
# Prompt: The future of education is
# Temperature: 1.0
# Top_k: 80
# Output: The future of education is now in limbo, and a whole bunch of things may be wrong with it."
#
# Oddly, it was even suggested that the Liberal Party is already under attack for its support for charter schools, in order to get behind their policies.
#
#
# ----------------------------------
# Prompt: The future of education is
# Temperature: 1.3
# Top_k: 20
# Output: The future of education is in the hands of an open source, transparent process." In the coming year, the project is already looking for a partner to help. For now, the only way to get it up and running is to build it out yourself or, as we hope
#
# ----------------------------------
# Prompt: The future of education is
# Temperature: 1.3
# Top_k: 40
# Output: The future of education is a question of where these lessons get learned. We've been doing well over the last half decade of having more teachers working longer hours, raising the standards of students on the whole in many small parts of the country, so that there's more people in
#
# ----------------------------------
# Prompt: The future of education is
# Temperature: 1.3
# Top_k: 80
# Output: The future of education is going to require this mentality to be expressed. Because, just as the past century is becoming obsolete in this one way and other ways by some new technologies," said Prof Thomas.
#
# The research will help understand why new technologies are becoming available. "
#
# ----------------------------------
# Prompt: Artificial Intelligence will
# Temperature: 0.7
# Top_k: 20
# Output: Artificial Intelligence will be able to recognize the human's emotions and the emotions of others.
#
# The next step is to create a system for AI that recognizes what the human is saying in the face of emotions. And this is a very difficult task. The human is
#
# ----------------------------------
# Prompt: Artificial Intelligence will
# Temperature: 0.7
# Top_k: 40
# Output: Artificial Intelligence will be used to better understand and understand the effects of technology that is affecting our lives. We will be able to better understand the consequences of technology and more effectively understand the impact of technologies on our lives, and we will be able to better understand and understand
#
# ----------------------------------
# Prompt: Artificial Intelligence will
# Temperature: 0.7
# Top_k: 80
# Output: Artificial Intelligence will focus on real-world applications that are often connected to a complex network of sensors that are part of larger networks of computers, rather than just hardware.
#
# The company expects to launch in 2015 and has plans to offer cloud-based applications in the
#
# ----------------------------------
# Prompt: Artificial Intelligence will
# Temperature: 1.0
# Top_k: 20
# Output: Artificial Intelligence will be able to solve this problem. But, there's no guarantee that AI will do it. If it's successful, we may find the same thing: robots could solve the whole problem of artificial intelligence. But if you're worried, that's when
#
# ----------------------------------
# Prompt: Artificial Intelligence will
# Temperature: 1.0
# Top_k: 40
# Output: Artificial Intelligence will also develop a suite of autonomous tools in the next few years based on its AI program.
#
# The company announced in January that it would begin selling its AI-powered artificial intelligence platform, Biorote, at its North Korean retail warehouse in Seoul
#
# ----------------------------------
# Prompt: Artificial Intelligence will
# Temperature: 1.0
# Top_k: 80
# Output: Artificial Intelligence will begin allowing developers to include smart devices in their apps. The company is looking to attract developers with the ability to deploy smart devices up to 3 terawatt power. Also, more high-tech companies are becoming interested in AI.
#
# There's
#
# ----------------------------------
# Prompt: Artificial Intelligence will
# Temperature: 1.3
# Top_k: 20
# Output: Artificial Intelligence will make the human species faster and better. It will be faster. Humans can now use AI as intelligence.
#
# And it's just about time…
#
# The world needs an AI. That's a good call.
#
# What's the point
#
# ----------------------------------
# Prompt: Artificial Intelligence will
# Temperature: 1.3
# Top_k: 40
# Output: Artificial Intelligence will soon make it more difficult than ever to automate your business decisions without having to learn or experience automated, and even more difficult than it is now. The current technology won't get your back, and its costs will go far. The technology can lead to
#
# ----------------------------------
# Prompt: Artificial Intelligence will
# Temperature: 1.3
# Top_k: 80
# Output: Artificial Intelligence will eventually surpass the amount of computers we have now, which we believe we've won. As a society — given AI's ability — it has the potential to completely change American politics throughout the world. Computers will eventually eliminate the obstacles that prevent people from
#
# ----------------------------------
# Prompt: India in 2050 will be
# Temperature: 0.7
# Top_k: 20
# Output: India in 2050 will be the biggest ever in history. It will bring a new generation of engineers and scientists into the world of robotics."
#
# The project is to be funded by a series of government-backed international projects including the National Research Council for Industrial Robots, a joint
#
# ----------------------------------
# Prompt: India in 2050 will be
# Temperature: 0.7
# Top_k: 40
# Output: India in 2050 will be about 35 million people. The average adult in India is expected to be five times as much as the average child. If the population rises to 41 million by 2050, the per capita income of India could rise to more than $20,000 per day
#
# ----------------------------------
# Prompt: India in 2050 will be
# Temperature: 0.7
# Top_k: 80
# Output: India in 2050 will be a significant contribution to global climate change, and the effects of climate change will be significantly amplified globally," said the US Department of Energy's Secretary of Energy Ernest Moniz.
#
# "That's why the US government is committed to working with the international
#
# ----------------------------------
# Prompt: India in 2050 will be
# Temperature: 1.0
# Top_k: 20
# Output: India in 2050 will be 50 percent lower than what India expects. India now consumes about 7.5 gallons of diesel per day compared to just 2.5 gallons of diesel produced in the 1990s.
#
# "This is a huge development in India," Dr. D.
#
# ----------------------------------
# Prompt: India in 2050 will be
# Temperature: 1.0
# Top_k: 40
# Output: India in 2050 will be over. More than a fifth of people live below the poverty line while nearly 90 per cent of people will have to cut their pensions in order to support their pensions at some point, if the country continues its economic slide," he said.
#
# "
#
# ----------------------------------
# Prompt: India in 2050 will be
# Temperature: 1.0
# Top_k: 80
# Output: India in 2050 will be able to export some 1 billion tonnes of fossil fuels (and thus up to 20 percent of emissions) through 2016, according to Gülen.
#
# The UN has estimated that Europe, North America, Central and South America will trade greenhouse gas gas
#
# ----------------------------------
# Prompt: India in 2050 will be
# Temperature: 1.3
# Top_k: 20
# Output: India in 2050 will be more than twice the number of states in the same sector. By the second quarter of this decade, states like Bihar, Maharashtra, Madhya Pradesh will have a combined total capacity of more than 20 trillion cubic metres of oil and natural resources, more than
#
# ----------------------------------
# Prompt: India in 2050 will be
# Temperature: 1.3
# Top_k: 40
# Output: India in 2050 will be expected to cover 20% of growth and 40%-50% share increase in its economy. It has already become apparent that even at 2% of GDP growth, India's industrial competitiveness and global leadership, despite its lack of GDP growth and poor governance,
#
# ----------------------------------
# Prompt: India in 2050 will be
# Temperature: 1.3
# Top_k: 80
# Output: India in 2050 will be worth approximately 26 billion, while their populations are estimated to grow nearly one-half that. The projected increase towards a nuclear energy generation output by 10 percent annually is to have potential world impacts over the period 2019-2040."
#
# The University of

# %%
import pandas as pd

df = pd.DataFrame(results)

# Show table
df
# Out:
#                           prompt  temperature  top_k  \
# 0     The future of education is          0.7     20
# 1     The future of education is          0.7     40
# 2     The future of education is          0.7     80
# 3     The future of education is          1.0     20
# 4     The future of education is          1.0     40
# 5     The future of education is          1.0     80
# 6     The future of education is          1.3     20
# 7     The future of education is          1.3     40
# 8     The future of education is          1.3     80
# 9   Artificial Intelligence will          0.7     20
# 10  Artificial Intelligence will          0.7     40
# 11  Artificial Intelligence will          0.7     80
# 12  Artificial Intelligence will          1.0     20
# 13  Artificial Intelligence will          1.0     40
# 14  Artificial Intelligence will          1.0     80
# 15  Artificial Intelligence will          1.3     20
# 16  Artificial Intelligence will          1.3     40
# 17  Artificial Intelligence will          1.3     80
# 18         India in 2050 will be          0.7     20
# 19         India in 2050 will be          0.7     40
# 20         India in 2050 will be          0.7     80
# 21         India in 2050 will be          1.0     20
# 22         India in 2050 will be          1.0     40
# 23         India in 2050 will be          1.0     80
# 24         India in 2050 will be          1.3     20
# 25         India in 2050 will be          1.3     40
# 26         India in 2050 will be          1.3     80
#
#                                                output
# 0   The future of education is now in doubt.\n\nA ...
# 1   The future of education is uncertain, and many...
# 2   The future of education is going to be determi...
# 3   The future of education is very uncertain," he...
# 4   The future of education is about developing id...
# 5   The future of education is now in limbo, and a...
# 6   The future of education is in the hands of an ...
# 7   The future of education is a question of where...
# 8   The future of education is going to require th...
# 9   Artificial Intelligence will be able to recogn...
# 10  Artificial Intelligence will be used to better...
# 11  Artificial Intelligence will focus on real-wor...
# 12  Artificial Intelligence will be able to solve ...
# 13  Artificial Intelligence will also develop a su...
# 14  Artificial Intelligence will begin allowing de...
# 15  Artificial Intelligence will make the human sp...
# 16  Artificial Intelligence will soon make it more...
# 17  Artificial Intelligence will eventually surpas...
# 18  India in 2050 will be the biggest ever in hist...
# 19  India in 2050 will be about 35 million people....
# 20  India in 2050 will be a significant contributi...
# 21  India in 2050 will be 50 percent lower than wh...
# 22  India in 2050 will be over. More than a fifth ...
# 23  India in 2050 will be able to export some 1 bi...
# 24  India in 2050 will be more than twice the numb...
# 25  India in 2050 will be expected to cover 20% of...
# 26  India in 2050 will be worth approximately 26 b...
