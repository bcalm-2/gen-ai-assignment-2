# %% [markdown]
# <a href="https://colab.research.google.com/github/bcalm-2/gen-ai-assignment-2/blob/main/GenAiAssignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (5.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.25.2)
# Requirement already satisfied: huggingface-hub<2.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (1.7.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from transformers) (0.24.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (1.4.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (0.28.1)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (0.24.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (4.15.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (4.12.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (0.16.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers) (0.1.2)

# %%
from transformers import GPT2LMHeadModel, GPT2Tokenizer

tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
model = GPT2LMHeadModel.from_pretrained("gpt2")
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
# Array of prompts
prompts = [
    "The future of education is",
    "Artificial Intelligence will",
    "India in 2050 will be"
]

def generate_text(prompt, top_k, temperature):
    inputs = tokenizer.encode(prompt, return_tensors="pt")

    output = model.generate(
        inputs,
        max_new_tokens=50,
        do_sample=True,
        top_k=top_k,
        temperature=temperature
    )

    return tokenizer.decode(output[0], skip_special_tokens=True)

# Run for all prompts
for prompt in prompts:
    print("\nPrompt:", prompt)
    result = generate_text(prompt, top_k=40, temperature=0.7)
    print("Output:", result)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Prompt: The future of education is
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Output: The future of education is in flux. The rise of Google has been seen as a signal to companies that they need to do more to promote their products. As the Internet continues to expand and evolve, so too will the number of people who use it.
#
# But even
#
# Prompt: Artificial Intelligence will
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Output: Artificial Intelligence will be a part of the "Billion Dollar Project" and it will not just have to solve the world's problems, but also our own.
#
# But is it a bad idea?
#
# "I think it's a good idea," said
#
# Prompt: India in 2050 will be
# Output: India in 2050 will be the first year that global emissions are at a historic level, and this is a good time for us to move forward," an official said.
#
# More about Global warming
#
# Hottest year on record
#
# Global warming continues to be a major

# %%
# Different values to test
temperatures = [0.7, 1.0, 1.3]
top_k_values = [20, 40, 80]

# Store results
results = []

for prompt in prompts:
    for temp in temperatures:
        for k in top_k_values:

            output = generate_text(prompt, top_k=k, temperature=temp)

            results.append({
                "prompt": prompt,
                "temperature": temp,
                "top_k": k,
                "output": output
            })

# Print results clearly
for r in results:
    print("\n----------------------------------")
    print("Prompt:", r["prompt"])
    print("Temperature:", r["temperature"])
    print("Top_k:", r["top_k"])
    print("Output:", r["output"])
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ----------------------------------
# Prompt: The future of education is
# Temperature: 0.7
# Top_k: 20
# Output: The future of education is not as bright as it once was.
#
# Education in America is not the future for our children. Education is the future of our world. Education is the future of America.
#
# I think that it's time for the federal government to recognize
#
# ----------------------------------
# Prompt: The future of education is
# Temperature: 0.7
# Top_k: 40
# Output: The future of education is about better education for all, and today's report shows that education is not something that can be left to private hands. It is not a matter of whether we have good public schools or not. It is a matter of whether education is a great success
#
# ----------------------------------
# Prompt: The future of education is
# Temperature: 0.7
# Top_k: 80
# Output: The future of education is in flux," said Kappos, who has been a professor of education at the University of Texas at Austin for 20 years. "It's not the end of it. It's going to go better."
#
# Kappos said he has
#
# ----------------------------------
# Prompt: The future of education is
# Temperature: 1.0
# Top_k: 20
# Output: The future of education is not a simple one. We've become accustomed to thinking about the past only in terms of the present." "We have been doing something new with the current school system. We've been doing something different with the curriculum and the school system. That's
#
# ----------------------------------
# Prompt: The future of education is
# Temperature: 1.0
# Top_k: 40
# Output: The future of education is one of a multitude; you will learn, and you will be good, to know what we have to do when education becomes a job, where we should all need to find a place in a big world, where we are capable of doing things,
#
# ----------------------------------
# Prompt: The future of education is
# Temperature: 1.0
# Top_k: 80
# Output: The future of education is uncertain because of rising income inequality and joblessness," the group said. "We are taking this opportunity to give the nation some clarity on the role of education in policy making and encourage investment in education by making opportunities available for everybody."
#
# A major
#
# ----------------------------------
# Prompt: The future of education is
# Temperature: 1.3
# Top_k: 20
# Output: The future of education is not a mystery. In spite of all that, there's never been a clear and unambiguous policy on what students should teach, whether on their own merits and on public or private grounds. As a result, the public sector must take into account and
#
# ----------------------------------
# Prompt: The future of education is
# Temperature: 1.3
# Top_k: 40
# Output: The future of education is unclear," says Professor David Breen, principal research officer on international standards and the chair of the Australian Association for Educational Quality
#
# He says if this changes, an increased number of children studying at a school would still not fit a specific teaching approach.
#
# ----------------------------------
# Prompt: The future of education is
# Temperature: 1.3
# Top_k: 80
# Output: The future of education is still in some unknown stage," she pointed out.
#
#
# ----------------------------------
# Prompt: Artificial Intelligence will
# Temperature: 0.7
# Top_k: 20
# Output: Artificial Intelligence will become a major topic of discussion in the next few years as technology advances, and how we think about the world around us is being developed. But AI is only one aspect of the picture. In fact, we need to look at this in a way
#
# ----------------------------------
# Prompt: Artificial Intelligence will
# Temperature: 0.7
# Top_k: 40
# Output: Artificial Intelligence will not become a force of nature. The technology is too small and too complex to be easily applied to individual tasks, and will only become more complex as information becomes more integrated into the fabric of the human brain.
#
# If this technology can be used
#
# ----------------------------------
# Prompt: Artificial Intelligence will
# Temperature: 0.7
# Top_k: 80
# Output: Artificial Intelligence will bring about profound changes for the future of life, and it is likely that our current systems will be unable to handle these changes.
#
# In the next few years, AI-driven robots will be able to replace human workers—whether it is in
#
# ----------------------------------
# Prompt: Artificial Intelligence will
# Temperature: 1.0
# Top_k: 20
# Output: Artificial Intelligence will soon be able to recognize the world around us and recognize what our environment looks like.
#
# The technology will help humans understand the way we use and manage our home environments. It may one day become an industry standard.
#
# However, there's
#
# ----------------------------------
# Prompt: Artificial Intelligence will
# Temperature: 1.0
# Top_k: 40
# Output: Artificial Intelligence will not only solve social problems within individuals and communities, but also provide opportunities for human-machine collaboration. The AI might be capable of learning from its user's actions, which could be used to design products that help those in need. And while this might
#
# ----------------------------------
# Prompt: Artificial Intelligence will
# Temperature: 1.0
# Top_k: 80
# Output: Artificial Intelligence will create some powerful machines to take over the world, it's being brought up by a member for the project, because technology is not to the right standard for a future to thrive on, despite what others can see. He claims there is "some big
#
# ----------------------------------
# Prompt: Artificial Intelligence will
# Temperature: 1.3
# Top_k: 20
# Output: Artificial Intelligence will be an important tool with this year as it is already a powerful platform. In other words: Artificial Intelligence will help you to solve all of your complex social problems. So, how will this technology impact your professional workflows?
#
# How Much Can
#
# ----------------------------------
# Prompt: Artificial Intelligence will
# Temperature: 1.3
# Top_k: 40
# Output: Artificial Intelligence will now be available to Linux by default! A new version of Unity's Autonaut was released, one more update and five new feature requests to take care of, all before we even knew we'd make Unity available to Linux. You can find the
#
# ----------------------------------
# Prompt: Artificial Intelligence will
# Temperature: 1.3
# Top_k: 80
# Output: Artificial Intelligence will be getting even more of the attention of law enforcement agencies after Microsoft, which is now headed by General Sir Nick Timothy Karpeles, recently expressed concern about the future of artificial intelligence in one interview with News Corp CEO Satya Nadella.
#
# ----------------------------------
# Prompt: India in 2050 will be
# Temperature: 0.7
# Top_k: 20
# Output: India in 2050 will be nearly twice as large as today's.
#
# The world will be the first country to have a carbon-free economy by 2030.
#
# According to the European Commission, the world is already on track to meet its emissions targets by 2040.
#
# ----------------------------------
# Prompt: India in 2050 will be
# Temperature: 0.7
# Top_k: 40
# Output: India in 2050 will be 10 times more expensive than in the 1960s.
#
# "This is what the government is trying to achieve," said Mr Haldane.
#
# "It is a total subsidy of $6.5 billion.
#
# "If that goes
#
# ----------------------------------
# Prompt: India in 2050 will be
# Temperature: 0.7
# Top_k: 80
# Output: India in 2050 will be the world's largest electricity generation station, with capacity of 1.4 gigawatts (GW), which is equivalent to about 18 percent of the country's electricity generation capacity.
#
# "We are already building up the capacity of our power stations to meet
#
# ----------------------------------
# Prompt: India in 2050 will be
# Temperature: 1.0
# Top_k: 20
# Output: India in 2050 will be the lowest in 10 years, and the global average will be only 13 per cent below today's average.
#
# This is the first time in 30 years that any country in the world is going to be above its 20 per cent target by 2050,
#
# ----------------------------------
# Prompt: India in 2050 will be
# Temperature: 1.0
# Top_k: 40
# Output: India in 2050 will be as low as half-a-million in India, with a huge impact to the economy, said the study. The study's authors suggest that we will get about half the country's population from non-permanent migrants.
#
# "One cannot
#
# ----------------------------------
# Prompt: India in 2050 will be
# Temperature: 1.0
# Top_k: 80
# Output: India in 2050 will be a much smaller population and are expected to sustain the average annual population of 10 billion by 2050. (Source)
#
# The total population of China is projected to grow to 34.4 billion by 2070, representing about 18% of China's
#
# ----------------------------------
# Prompt: India in 2050 will be
# Temperature: 1.3
# Top_k: 20
# Output: India in 2050 will be the largest of that decade in terms of CO2 emission," says Ramesh Prasad, a professor of atmospheric sciences at the Indian Institute of Science and Technology in Bangalore.
#
# ----------------------------------
# Prompt: India in 2050 will be
# Temperature: 1.3
# Top_k: 40
# Output: India in 2050 will be as much more than twice the population of a comparable state. This means that India already has the best health care system but in fact the poorest state may have the highest quality of life," Dr V.R. Raghavan has written in the Indian
#
# ----------------------------------
# Prompt: India in 2050 will be
# Temperature: 1.3
# Top_k: 80
# Output: India in 2050 will be 25 million people, in 2050 the number will grow to 250 million; by 2100 China will have 230 million people or 0.3 percent of global population, in 2030 with 100 million people per year if people migrate at the age of 10 years or older

# %%
import pandas as pd

df = pd.DataFrame(results)

# Show table
df
# Out:
#                           prompt  temperature  top_k  \
# 0     The future of education is          0.7     20
# 1     The future of education is          0.7     40
# 2     The future of education is          0.7     80
# 3     The future of education is          1.0     20
# 4     The future of education is          1.0     40
# 5     The future of education is          1.0     80
# 6     The future of education is          1.3     20
# 7     The future of education is          1.3     40
# 8     The future of education is          1.3     80
# 9   Artificial Intelligence will          0.7     20
# 10  Artificial Intelligence will          0.7     40
# 11  Artificial Intelligence will          0.7     80
# 12  Artificial Intelligence will          1.0     20
# 13  Artificial Intelligence will          1.0     40
# 14  Artificial Intelligence will          1.0     80
# 15  Artificial Intelligence will          1.3     20
# 16  Artificial Intelligence will          1.3     40
# 17  Artificial Intelligence will          1.3     80
# 18         India in 2050 will be          0.7     20
# 19         India in 2050 will be          0.7     40
# 20         India in 2050 will be          0.7     80
# 21         India in 2050 will be          1.0     20
# 22         India in 2050 will be          1.0     40
# 23         India in 2050 will be          1.0     80
# 24         India in 2050 will be          1.3     20
# 25         India in 2050 will be          1.3     40
# 26         India in 2050 will be          1.3     80
#
#                                                output
# 0   The future of education is not as bright as it...
# 1   The future of education is about better educat...
# 2   The future of education is in flux," said Kapp...
# 3   The future of education is not a simple one. W...
# 4   The future of education is one of a multitude;...
# 5   The future of education is uncertain because o...
# 6   The future of education is not a mystery. In s...
# 7   The future of education is unclear," says Prof...
# 8   The future of education is still in some unkno...
# 9   Artificial Intelligence will become a major to...
# 10  Artificial Intelligence will not become a forc...
# 11  Artificial Intelligence will bring about profo...
# 12  Artificial Intelligence will soon be able to r...
# 13  Artificial Intelligence will not only solve so...
# 14  Artificial Intelligence will create some power...
# 15  Artificial Intelligence will be an important t...
# 16  Artificial Intelligence will now be available ...
# 17  Artificial Intelligence will be getting even m...
# 18  India in 2050 will be nearly twice as large as...
# 19  India in 2050 will be 10 times more expensive ...
# 20  India in 2050 will be the world's largest elec...
# 21  India in 2050 will be the lowest in 10 years, ...
# 22  India in 2050 will be as low as half-a-million...
# 23  India in 2050 will be a much smaller populatio...
# 24  India in 2050 will be the largest of that deca...
# 25  India in 2050 will be as much more than twice ...
# 26  India in 2050 will be 25 million people, in 20...
