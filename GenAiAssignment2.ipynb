# %% [markdown]
# <a href="https://colab.research.google.com/github/bcalm-2/gen-ai-assignment-2/blob/main/GenAiAssignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (5.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.25.2)
# Requirement already satisfied: huggingface-hub<2.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (1.7.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from transformers) (0.24.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (1.4.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (0.28.1)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (0.24.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (4.15.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (4.12.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (0.16.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers) (0.1.2)

# %%
from transformers import GPT2LMHeadModel, GPT2Tokenizer

tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
model = GPT2LMHeadModel.from_pretrained("gpt2")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]

# %%
# Array of prompts
prompts = [
    "The future of education is",
    "Artificial Intelligence will",
    "India in 2050 will be"
]

def generate_text(prompt, top_k, temperature):
    inputs = tokenizer.encode(prompt, return_tensors="pt")

    output = model.generate(
        inputs,
        max_new_tokens=50,
        do_sample=True,
        top_k=top_k,
        temperature=temperature
    )

    return tokenizer.decode(output[0], skip_special_tokens=True)

# Run for all prompts
for prompt in prompts:
    print("\nPrompt:", prompt)
    result = generate_text(prompt, top_k=40, temperature=0.7)
    print("Output:", result)
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Prompt: The future of education is
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Output: The future of education is still up in the air.
#
# The first of these is the idea of a basic income for all, a basic income for all in Europe and in the UK.
#
# The goal is to raise €90 per week for people with no qualifications
#
# Prompt: Artificial Intelligence will
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Output: Artificial Intelligence will be the next big thing.
#
# That's why I think it's very important for all of us to think about AI as something that can be applied to any job, and not just one.
#
# On the AI business, it's obvious
#
# Prompt: India in 2050 will be
# Output: India in 2050 will be more than six times more likely to be affected by floods than it is today," the study concluded.
#
# The study is part of the Global Floods Challenge, the largest study to date on climate change, which aims to provide a global baseline for

# %%
# Different values to test
temperatures = [0.7, 1.0, 1.3]
top_k_values = [20, 40, 80]

# Store results
results = []

for prompt in prompts:
    for temp in temperatures:
        for k in top_k_values:

            output = generate_text(prompt, top_k=k, temperature=temp)

            results.append({
                "prompt": prompt,
                "temperature": temp,
                "top_k": k,
                "output": output
            })

# Print results clearly
for r in results:
    print("\n----------------------------------")
    print("Prompt:", r["prompt"])
    print("Temperature:", r["temperature"])
    print("Top_k:", r["top_k"])
    print("Output:", r["output"])
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ----------------------------------
# Prompt: The future of education is
# Temperature: 0.7
# Top_k: 20
# Output: The future of education is in the hands of young people, but it does not mean that education should be taught by adults. It can be taught by parents. It can be taught by teachers working with pupils. It can be taught by students working with teachers. The current government
#
# ----------------------------------
# Prompt: The future of education is
# Temperature: 0.7
# Top_k: 40
# Output: The future of education is a challenge."
#
# It would be a miracle to prevent the rise in the number of children being shot, but the most likely outcome would be that the number of children dying of mental illness will rise.
#
# "The mental health system needs to
#
# ----------------------------------
# Prompt: The future of education is
# Temperature: 0.7
# Top_k: 80
# Output: The future of education is a different story. We are in a very uncertain time if we are going to see progress for all students," says Ben Ainslie, head of public education at the National Society of American College-Educators. "And there's no future for
#
# ----------------------------------
# Prompt: The future of education is
# Temperature: 1.0
# Top_k: 20
# Output: The future of education is being threatened by a new generation of billionaires who are trying to dominate our educational system and the public sphere."
#
# ----------------------------------
# Prompt: The future of education is
# Temperature: 1.0
# Top_k: 40
# Output: The future of education is not a choice. It is a choice to keep the same educational standards, and keep jobs as long as it costs you to maintain them.
#
# I'm sure you can see the point. But this isn't the time. A decade from now
#
# ----------------------------------
# Prompt: The future of education is
# Temperature: 1.0
# Top_k: 80
# Output: The future of education is uncertain.
#
# The school-the-next day mantra
#
# The most compelling aspect of the job opportunities available in China have some sort of meritocracy clause. As a professor of political science at the Shanghai IIT city-level , I've
#
# ----------------------------------
# Prompt: The future of education is
# Temperature: 1.3
# Top_k: 20
# Output: The future of education is a mess of problems, so we need more solutions. And that's what we've found. A lot of people believe that in the US, education is still a bad concept," she added.
#
# ----------------------------------
# Prompt: The future of education is
# Temperature: 1.3
# Top_k: 40
# Output: The future of education is being driven primarily by students. Many are students enrolled or already going to college."The next generation can expect to end up not doing science, but instead doing business and working on small businesses or taking a few years out before taking a major. In my
#
# ----------------------------------
# Prompt: The future of education is
# Temperature: 1.3
# Top_k: 80
# Output: The future of education is the world has never witnessed the triumph, that has unfolded rapidly enough through globalization and automation and robotics, from child of poverty: now a great nation needs schools and technology and technology is all for naught. Therefore the next paradigm shift in the education sector
#
# ----------------------------------
# Prompt: Artificial Intelligence will
# Temperature: 0.7
# Top_k: 20
# Output: Artificial Intelligence will use the same tools that have been used in science fiction to solve problems for years, and it will be able to adapt to the challenges that are presented.
#
# And if you are not familiar with Artificial Intelligence, you may have never heard of it
#
# ----------------------------------
# Prompt: Artificial Intelligence will
# Temperature: 0.7
# Top_k: 40
# Output: Artificial Intelligence will be our next big thing.
#
# The most important thing to understand about Artificial Intelligence is that it's more than just a tool. It's a system that can perform tasks in a human-like way. When you walk around a room, your
#
# ----------------------------------
# Prompt: Artificial Intelligence will
# Temperature: 0.7
# Top_k: 80
# Output: Artificial Intelligence will be a great way to get to know each other, and to know where we are going, and when we're going to be in the same place. It's a new, different kind of technological world. And it's a new kind of human
#
# ----------------------------------
# Prompt: Artificial Intelligence will
# Temperature: 1.0
# Top_k: 20
# Output: Artificial Intelligence will be the first to use machine learning to determine a person's personality. Machine learning has been used to predict crime rates in prisons for over a century, but it's not a particularly sophisticated way to do it. This article will be focused on how machines
#
# ----------------------------------
# Prompt: Artificial Intelligence will
# Temperature: 1.0
# Top_k: 40
# Output: Artificial Intelligence will be able to analyze anything in our data and work with it to help improve our algorithms. We will also be able to improve our tools to create new and exciting projects, as well as our applications. In addition to these, we want to help our
#
# ----------------------------------
# Prompt: Artificial Intelligence will
# Temperature: 1.0
# Top_k: 80
# Output: Artificial Intelligence will be capable of doing that for me. So, I look forward to learning more.
#
# — Jonathan D. Parry
#
# Image courtesy
#
# This article first appeared on The Wire.
#
# ----------------------------------
# Prompt: Artificial Intelligence will
# Temperature: 1.3
# Top_k: 20
# Output: Artificial Intelligence will not only improve the capabilities of artificial intelligence, it will also provide an important foundation for human society. In an open discussion of this subject, Dr. Robert Gentry has recently conducted a paper entitled Understanding Artificial Intelligence with Computer Science, which will address this
#
# ----------------------------------
# Prompt: Artificial Intelligence will
# Temperature: 1.3
# Top_k: 40
# Output: Artificial Intelligence will soon be able to solve almost any of these cognitive tasks — and even some of the more elusive types of abstract problem-solving. A good example is a machine's ability to process input-output signals in a machine that can determine the order and
#
# ----------------------------------
# Prompt: Artificial Intelligence will
# Temperature: 1.3
# Top_k: 80
# Output: Artificial Intelligence will enable the machines to become more capable by sharing and managing more information at a shorter timeline
#
# The technologies being announced are only just beginning
#
# The tech involves two main pillars: Intelligent communication and more efficient system design
#
# Researchers from MIT, The
#
# ----------------------------------
# Prompt: India in 2050 will be
# Temperature: 0.7
# Top_k: 20
# Output: India in 2050 will be the largest and most disruptive transformation of any major industrial industry in history," said Dr. A.M. Bhat, head of the Institute of Advanced Technology in Beijing.
#
# "We are on the brink of a revolution because today's technologies are
#
# ----------------------------------
# Prompt: India in 2050 will be
# Temperature: 0.7
# Top_k: 40
# Output: India in 2050 will be more than twice as large as the world's population.
#
# In the past three decades, the world has seen a huge increase in the number of people living in poverty. In the last decade, around a third of world's population has been classified
#
# ----------------------------------
# Prompt: India in 2050 will be
# Temperature: 0.7
# Top_k: 80
# Output: India in 2050 will be the biggest carbon emission of all — in the world, by far.
#
# The first step for renewables will be to create enough energy to power the world's first coal-fired power plant, which will supply electricity to the world's third-big
#
# ----------------------------------
# Prompt: India in 2050 will be
# Temperature: 1.0
# Top_k: 20
# Output: India in 2050 will be the largest in the world.
#
# The report said the country will reach 1.8 billion people by 2050 and the number will exceed 100 million people by 2050, making it the second biggest nation in the world. "With this increase, the world
#
# ----------------------------------
# Prompt: India in 2050 will be
# Temperature: 1.0
# Top_k: 40
# Output: India in 2050 will be a decade ago, and the global economy will be 20 percent smaller on average by 2050," said Jangmai Dhillon, chief executive officer of Arup. "This will mean less government spending in education, health, welfare and security."
#
# ----------------------------------
# Prompt: India in 2050 will be
# Temperature: 1.0
# Top_k: 80
# Output: India in 2050 will be more than triple that.
#
# For every 10 emissions produced in 2050 with emissions of 1.5 tonnes, only 1.1 tonnes of air pollution are emitted to prevent global warming. That doesn't even include carbonated waste products, which emit an
#
# ----------------------------------
# Prompt: India in 2050 will be
# Temperature: 1.3
# Top_k: 20
# Output: India in 2050 will be one of the hottest in the world. The country will become the third largest economy in the world with population growing at the fastest rate of growth in the 20th century. The country's infrastructure is at capacity, which can take many decades to fully mature
#
# ----------------------------------
# Prompt: India in 2050 will be
# Temperature: 1.3
# Top_k: 40
# Output: India in 2050 will be an economic, technological, social, energy and environmental priority," said a statement issued by the Office's Secretary-General Jutinder Singh Naidu after the meeting on Friday. Singh, the senior civil servant, who had recently left the department with
#
# ----------------------------------
# Prompt: India in 2050 will be
# Temperature: 1.3
# Top_k: 80
# Output: India in 2050 will be achieved with a cost-savings target that reaches £60bn, a plan being based at Oxford University.The new, low-cost emissions standard will provide much needed security and make for effective emissions reductions along road corridors globally, experts said. The

# %%
import pandas as pd

df = pd.DataFrame(results)

# Show table
df
# Out:
#                           prompt  temperature  top_k  \
# 0     The future of education is          0.7     20
# 1     The future of education is          0.7     40
# 2     The future of education is          0.7     80
# 3     The future of education is          1.0     20
# 4     The future of education is          1.0     40
# 5     The future of education is          1.0     80
# 6     The future of education is          1.3     20
# 7     The future of education is          1.3     40
# 8     The future of education is          1.3     80
# 9   Artificial Intelligence will          0.7     20
# 10  Artificial Intelligence will          0.7     40
# 11  Artificial Intelligence will          0.7     80
# 12  Artificial Intelligence will          1.0     20
# 13  Artificial Intelligence will          1.0     40
# 14  Artificial Intelligence will          1.0     80
# 15  Artificial Intelligence will          1.3     20
# 16  Artificial Intelligence will          1.3     40
# 17  Artificial Intelligence will          1.3     80
# 18         India in 2050 will be          0.7     20
# 19         India in 2050 will be          0.7     40
# 20         India in 2050 will be          0.7     80
# 21         India in 2050 will be          1.0     20
# 22         India in 2050 will be          1.0     40
# 23         India in 2050 will be          1.0     80
# 24         India in 2050 will be          1.3     20
# 25         India in 2050 will be          1.3     40
# 26         India in 2050 will be          1.3     80
#
#                                                output
# 0   The future of education is in the hands of you...
# 1   The future of education is a challenge."\n\nIt...
# 2   The future of education is a different story. ...
# 3   The future of education is being threatened by...
# 4   The future of education is not a choice. It is...
# 5   The future of education is uncertain.\n\nThe s...
# 6   The future of education is a mess of problems,...
# 7   The future of education is being driven primar...
# 8   The future of education is the world has never...
# 9   Artificial Intelligence will use the same tool...
# 10  Artificial Intelligence will be our next big t...
# 11  Artificial Intelligence will be a great way to...
# 12  Artificial Intelligence will be the first to u...
# 13  Artificial Intelligence will be able to analyz...
# 14  Artificial Intelligence will be capable of doi...
# 15  Artificial Intelligence will not only improve ...
# 16  Artificial Intelligence will soon be able to s...
# 17  Artificial Intelligence will enable the machin...
# 18  India in 2050 will be the largest and most dis...
# 19  India in 2050 will be more than twice as large...
# 20  India in 2050 will be the biggest carbon emiss...
# 21  India in 2050 will be the largest in the world...
# 22  India in 2050 will be a decade ago, and the gl...
# 23  India in 2050 will be more than triple that.\n...
# 24  India in 2050 will be one of the hottest in th...
# 25  India in 2050 will be an economic, technologic...
# 26  India in 2050 will be achieved with a cost-sav...
