# %% [markdown]
# <a href="https://colab.research.google.com/github/bcalm-2/gen-ai-assignment-2/blob/main/GenAiAssignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (5.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.25.2)
# Requirement already satisfied: huggingface-hub<2.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (1.7.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from transformers) (0.24.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (1.4.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (0.28.1)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (0.24.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (4.15.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (4.12.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (0.16.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers) (0.1.2)

# %%
from transformers import GPT2LMHeadModel, GPT2Tokenizer

tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
model = GPT2LMHeadModel.from_pretrained("gpt2")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]

# %%
# Array of prompts
prompts = [
    "The future of education is",
    "Artificial Intelligence will",
    "India in 2050 will be"
]

def generate_text(prompt, top_k, temperature):
    inputs = tokenizer.encode(prompt, return_tensors="pt")

    output = model.generate(
        inputs,
        max_new_tokens=50,
        do_sample=True,
        top_k=top_k,
        temperature=temperature
    )

    return tokenizer.decode(output[0], skip_special_tokens=True)

# Run for all prompts
for prompt in prompts:
    print("\nPrompt:", prompt)
    result = generate_text(prompt, top_k=40, temperature=0.7)
    print("Output:", result)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Prompt: The future of education is
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Output: The future of education is about educating the next generation of people
#
# "The government's budget is one of the most important pieces of legislation in the world. It's a very important piece of legislation. And we're not going to allow a small number of people to be
#
# Prompt: Artificial Intelligence will
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Output: Artificial Intelligence will continue to evolve as we know it, and continue to evolve to meet the needs of today's increasingly diverse workforce.
#
# In the coming years, we will continue to grow the number of developers working on artificial intelligence in our industry by more than a
#
# Prompt: India in 2050 will be
# Output: India in 2050 will be more than twice as large as today's, with an estimated 766 million people in Delhi, and more than 60 percent of them children. India's growth rate will be even more dramatic.
#
# The number of people living in India is growing by

# %%
# Different values to test
temperatures = [0.7, 1.0, 1.3]
top_k_values = [20, 40, 80]

# Store results
results = []

for prompt in prompts:
    for temp in temperatures:
        for k in top_k_values:

            output = generate_text(prompt, top_k=k, temperature=temp)

            results.append({
                "prompt": prompt,
                "temperature": temp,
                "top_k": k,
                "output": output
            })

# Print results clearly
for r in results:
    print("\n----------------------------------")
    print("Prompt:", r["prompt"])
    print("Temperature:", r["temperature"])
    print("Top_k:", r["top_k"])
    print("Output:", r["output"])
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ----------------------------------
# Prompt: The future of education is
# Temperature: 0.7
# Top_k: 20
# Output: The future of education is a multi-faceted one. In the United States, we have a very large number of students who are not able to get a college degree, so we have a large number of students who are not able to get a college degree and so
#
# ----------------------------------
# Prompt: The future of education is
# Temperature: 0.7
# Top_k: 40
# Output: The future of education is a complex subject.
#
# The most important question for policymakers is: Is education a good idea or a bad idea? It is a very serious question.
#
# I think we are in a position where there is a lot of good news.
#
#
# ----------------------------------
# Prompt: The future of education is
# Temperature: 0.7
# Top_k: 80
# Output: The future of education is in danger
#
# In a country where more than eight million students are in low-income households, little change is expected.
#
# Nationally, there is a high level of poverty among the population. But there are also significant concerns about the growing
#
# ----------------------------------
# Prompt: The future of education is
# Temperature: 1.0
# Top_k: 20
# Output: The future of education is the promise of free education. If we don't take this seriously, it will lead to many negative outcomes. There is no doubt that education is the key to economic well-being. And there has been an attempt by many countries to impose free trade
#
# ----------------------------------
# Prompt: The future of education is
# Temperature: 1.0
# Top_k: 40
# Output: The future of education is a complex landscape," he said.
#
# "As we stand on the brink of an uncertain future, the challenge with learning is that the world is being destroyed, with teachers becoming too expensive, too rigid."
#
# The move by the government to
#
# ----------------------------------
# Prompt: The future of education is
# Temperature: 1.0
# Top_k: 80
# Output: The future of education is being threatened by an aging population and the growing percentage of young people who can't afford school. Unfortunately, social media and social media messaging technologies are not giving parents the choice how to teach their kids in school. They may want to teach their children reading
#
# ----------------------------------
# Prompt: The future of education is
# Temperature: 1.3
# Top_k: 20
# Output: The future of education is at stake, and students have to make smart choice choices."
#
# A new study by the UCL Programme for International Student Life in partnership with the UCL Centre for Higher Education Research on the UK-China relationship shows a clear divide between education and
#
# ----------------------------------
# Prompt: The future of education is
# Temperature: 1.3
# Top_k: 40
# Output: The future of education is unclear, although they've been very positive."
#
# As he spoke, Trump continued to tell a gathered group of about 45 women in Washington that there is a "long-term" struggle underway against sexual harassment at school, and that there have been
#
# ----------------------------------
# Prompt: The future of education is
# Temperature: 1.3
# Top_k: 80
# Output: The future of education is now not quite over."
#
# ----------------------------------
# Prompt: Artificial Intelligence will
# Temperature: 0.7
# Top_k: 20
# Output: Artificial Intelligence will be able to understand the world around us and be able to find the answers to the questions we have. We will be able to create better, more personalized, and better connected communities and we will be able to create more sustainable solutions for these problems.
#
# ----------------------------------
# Prompt: Artificial Intelligence will
# Temperature: 0.7
# Top_k: 40
# Output: Artificial Intelligence will be used to build a "comprehensive set of tools for the AI in software that will be used on the battlefield in the years to come." The researchers added that they will also use "a new type of AI called 'superintelligence'
#
# ----------------------------------
# Prompt: Artificial Intelligence will
# Temperature: 0.7
# Top_k: 80
# Output: Artificial Intelligence will be available to run social networks, with an Intel architecture set to allow them to connect to sites like Facebook.
#
# "It's going to be a very dynamic world," said Mike Meehan, chief technology officer at Google, in a statement
#
# ----------------------------------
# Prompt: Artificial Intelligence will
# Temperature: 1.0
# Top_k: 20
# Output: Artificial Intelligence will be a top-down learning system where the user is guided through the experience of interacting with an AI that is using its brains. This is where things like artificial intelligence will begin.
#
# "AI is going to be a top-down learning system
#
# ----------------------------------
# Prompt: Artificial Intelligence will
# Temperature: 1.0
# Top_k: 40
# Output: Artificial Intelligence will be used at a high degree of sophistication. It will not allow, for example, a machine to learn how to pick up a person's hand. If AI does not do a good job of recognizing certain signs in the crowd that would mean that it
#
# ----------------------------------
# Prompt: Artificial Intelligence will
# Temperature: 1.0
# Top_k: 80
# Output: Artificial Intelligence will allow us to live in the future, a future in which all information is stored on remote servers across decades of physical spaces. This idea of the future is really something no one can deny, much less talk about it.
#
# On the left,
#
# ----------------------------------
# Prompt: Artificial Intelligence will
# Temperature: 1.3
# Top_k: 20
# Output: Artificial Intelligence will be used as the backbone for AI for many decades to come. As such, this has the potential to become an integral component in a lot of new projects. But it's also the most interesting part about Artificial Intelligence. Here is the most interesting part
#
# ----------------------------------
# Prompt: Artificial Intelligence will
# Temperature: 1.3
# Top_k: 40
# Output: Artificial Intelligence will now not need to rely on a processor power management system such as Intel's Core CPU and NVIDIA's Kepler chip, but they now need both to use as the cores. The Intel Riva 16 has eight CPU cores using 3.5" memory to
#
# ----------------------------------
# Prompt: Artificial Intelligence will
# Temperature: 1.3
# Top_k: 80
# Output: Artificial Intelligence will create 'decay rates' at its worst - an AI that can reach down to 13 percent of total human memory. To that end, it says artificial intelligence cannot understand how something happens - e.g. the car may not accelerate as best it
#
# ----------------------------------
# Prompt: India in 2050 will be
# Temperature: 0.7
# Top_k: 20
# Output: India in 2050 will be the lowest since the 1980s, with India's GDP at 5.3% of world GDP.
#
# China and India are set to make up the largest share of global oil production by 2030, with India's output expected to grow by nearly 3
#
# ----------------------------------
# Prompt: India in 2050 will be
# Temperature: 0.7
# Top_k: 40
# Output: India in 2050 will be the world's largest economy by 2030, according to the World Bank. The UN has projected that the world will have a net increase of 6.2 percent from 2050 to 2040.
#
# According to the World Bank, the global economy is projected
#
# ----------------------------------
# Prompt: India in 2050 will be
# Temperature: 0.7
# Top_k: 80
# Output: India in 2050 will be a decade later.
#
# "The current generation of workers will reach 1.4 million by 2025," said Mr. Khatri, who was the deputy premier of Gujarat's Rajasthan state for agriculture, irrigation and coastal development. "They
#
# ----------------------------------
# Prompt: India in 2050 will be
# Temperature: 1.0
# Top_k: 20
# Output: India in 2050 will be at its fastest rate in 100 years.
#
# "We're hoping that with this rapid growth rate the economy of Europe (and) China will be able to take over from the former Soviet Union and the rest of Asia too," said Dr. H
#
# ----------------------------------
# Prompt: India in 2050 will be
# Temperature: 1.0
# Top_k: 40
# Output: India in 2050 will be at least 20% higher for India, as well as higher growth for China, according to a study released Monday that was released by the government under a new development initiative.
#
# That number could rise to 35% in the years to 2050, the
#
# ----------------------------------
# Prompt: India in 2050 will be
# Temperature: 1.0
# Top_k: 80
# Output: India in 2050 will be the biggest population increase of the entire continent over this time period. This will keep pace with rising production and demand and would provide increased wealth and social security for the first time. This is extremely important to achieve this goal, which will also mean lower unemployment
#
# ----------------------------------
# Prompt: India in 2050 will be
# Temperature: 1.3
# Top_k: 20
# Output: India in 2050 will be reduced to $12.5 trillion from an earlier target of $20.5 trillion.
#
# As the global price tag for energy continues to increase, the United States will have $4.35 trillion of fossil-fuel subsidies.
#
# According
#
# ----------------------------------
# Prompt: India in 2050 will be
# Temperature: 1.3
# Top_k: 40
# Output: India in 2050 will be under the auspices of India and the European Commission, said Rajendra Singh, senior CTO, India in 2050: "Indigenous Indians will enjoy a significant and high-impact land conservation and social enhancement, due to their diverse nature and knowledge as
#
# ----------------------------------
# Prompt: India in 2050 will be
# Temperature: 1.3
# Top_k: 80
# Output: India in 2050 will be one of the biggest emitters of greenhouse gas emissions (1). As it grows less carbon dioxide, and there are no growing number of transatlantic flights between the US, EU, Brazil, India and Africa, the volume of these flights and the relative

# %%
import pandas as pd

df = pd.DataFrame(results)

# Show table
df
# Out:
#                           prompt  temperature  top_k  \
# 0     The future of education is          0.7     20
# 1     The future of education is          0.7     40
# 2     The future of education is          0.7     80
# 3     The future of education is          1.0     20
# 4     The future of education is          1.0     40
# 5     The future of education is          1.0     80
# 6     The future of education is          1.3     20
# 7     The future of education is          1.3     40
# 8     The future of education is          1.3     80
# 9   Artificial Intelligence will          0.7     20
# 10  Artificial Intelligence will          0.7     40
# 11  Artificial Intelligence will          0.7     80
# 12  Artificial Intelligence will          1.0     20
# 13  Artificial Intelligence will          1.0     40
# 14  Artificial Intelligence will          1.0     80
# 15  Artificial Intelligence will          1.3     20
# 16  Artificial Intelligence will          1.3     40
# 17  Artificial Intelligence will          1.3     80
# 18         India in 2050 will be          0.7     20
# 19         India in 2050 will be          0.7     40
# 20         India in 2050 will be          0.7     80
# 21         India in 2050 will be          1.0     20
# 22         India in 2050 will be          1.0     40
# 23         India in 2050 will be          1.0     80
# 24         India in 2050 will be          1.3     20
# 25         India in 2050 will be          1.3     40
# 26         India in 2050 will be          1.3     80
#
#                                                output
# 0   The future of education is a multi-faceted one...
# 1   The future of education is a complex subject.\...
# 2   The future of education is in danger\n\nIn a c...
# 3   The future of education is the promise of free...
# 4   The future of education is a complex landscape...
# 5   The future of education is being threatened by...
# 6   The future of education is at stake, and stude...
# 7   The future of education is unclear, although t...
# 8     The future of education is now not quite over."
# 9   Artificial Intelligence will be able to unders...
# 10  Artificial Intelligence will be used to build ...
# 11  Artificial Intelligence will be available to r...
# 12  Artificial Intelligence will be a top-down lea...
# 13  Artificial Intelligence will be used at a high...
# 14  Artificial Intelligence will allow us to live ...
# 15  Artificial Intelligence will be used as the ba...
# 16  Artificial Intelligence will now not need to r...
# 17  Artificial Intelligence will create 'decay rat...
# 18  India in 2050 will be the lowest since the 198...
# 19  India in 2050 will be the world's largest econ...
# 20  India in 2050 will be a decade later.\n\n"The ...
# 21  India in 2050 will be at its fastest rate in 1...
# 22  India in 2050 will be at least 20% higher for ...
# 23  India in 2050 will be the biggest population i...
# 24  India in 2050 will be reduced to $12.5 trillio...
# 25  India in 2050 will be under the auspices of In...
# 26  India in 2050 will be one of the biggest emitt...
